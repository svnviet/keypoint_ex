# %%
import numpy as np
import json

with open('keypoint_labels.json') as json_file:
    data = json.load(json_file)

# %%
data
# Out:
# {'F_353253074480151_20181019093117.png': {'bl_upper_block': {'x': 682,
#    'y': 212},
#   'ul_bottom_block': {'x': 756, 'y': 512},
#   'ur_bottom_block': {'x': 919, 'y': 517}},
#  'F_353253075689131_20181012101508.png': {'bl_upper_block': {'x': 690,
#    'y': 256},
#   'ul_bottom_block': {'x': 762, 'y': 552},
#   'ur_bottom_block': {'x': 924, 'y': 556}},
#  'F_353253078273180_20180928082200.png': {'bl_upper_block': {'x': 668,
#    'y': 224},
#   'ul_bottom_block': {'x': 738, 'y': 528},
#   'ur_bottom_block': {'x': 904, 'y': 533}},
#  'F_353254071788794_20181004123342.png': {'bl_upper_block': {'x': 680,
#    'y': 251},
#   'ul_bottom_block': {'x': 749, 'y': 554},
#   'ur_bottom_block': {'x': 915, 'y': 562}},
#  'F_353255074182273_20181010033823.png': {'bl_upper_block': {'x': 691,
#    'y': 226},
#   'ul_bottom_block': {'x': 758, 'y': 520},
#   'ur_bottom_block': {'x': 923, 'y': 527}},
#  'F_353255077752130_20180928114622.png': {'bl_upper_block': {'x': 684,
#    'y': 234},
# ...

# %%
len(data)
# Out:
# 150

# %%
Nimg=list(data)[0]
Nimg
# Out:
# 'F_353253074480151_20181019093117.png'

# %%
data[Nimg].keys()
# Out:
# dict_keys(['bl_upper_block', 'ul_bottom_block', 'ur_bottom_block'])

# %%
Npoint=data[Nimg]['bl_upper_block']
Npoint
# Out:
# {'x': 682, 'y': 212}

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2

# %%
img = mpimg.imread('dataset/'+Nimg)
imgplot = plt.imshow(img)

# %%
img = cv2.circle(img, (Npoint['x'],Npoint['y']),10,(0, 0, 255), -1)
plt.imshow(img)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
img = cv2.circle(img, (data[Nimg]['ul_bottom_block']['x'],data[Nimg]['ul_bottom_block']['y']),10,(0, 0, 255), -1)
img = cv2.circle(img, (data[Nimg]['ur_bottom_block']['x'],data[Nimg]['ur_bottom_block']['y']),10,(0, 0, 255), -1)
plt.imshow(img)
with open('img.png','wb') as f:
    f.write(img)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
img.shape
# Out:
# (688, 1032, 3)

# %%
Key_point= list(data['F_353253074480151_20181019093117.png'])
# Dir_dt= 'dataset/'
i= 0
for image in data:
    img = mpimg.imread('dataset/'+image)
    for point in Key_point:
        img = cv2.circle(img, (data[image][point]['x'],data[image][point]['y']), 5,(0,0, 255), -1)
    plt.figure()
    plt.imshow(img)
    i+=1
    if i ==10:
        break
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from IPython.display import clear_output
from time import sleep
import os

# %%
# images=[]
# for image in data:
#     img =mpimg.imread('dataset/'+image)

# %%
data[image][point]['x'],data[image][point]['y']
# Out:
# (917, 518)

# %%
import cv2

# %%
c=cv2.imread('dataset/F_353253074480151_20181019093117.png')

# %%
import numpy as np
import json
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
